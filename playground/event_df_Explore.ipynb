# %%
import pandas as pd

# %%
events = pd.read_csv("../output_events/events-t-t_all.csv")

# %%
events
# Out:
#      theme         type structure     numer    tense     polarity  \
# 0   health  declarative    simple  singular  present  affirmative
# 1   health  declarative    simple  singular  present  affirmative
# 2   health  declarative    simple  singular  present  affirmative
# 3   nature  declarative    simple  singular  present  affirmative
# 4   nature  declarative    simple  singular  present  affirmative
# 5   nature  declarative    simple  singular  present  affirmative
# 6      NaN          NaN       NaN       NaN      NaN          NaN
# 7      NaN          NaN       NaN       NaN      NaN          NaN
# 8      NaN          NaN       NaN       NaN      NaN          NaN
# 9      NaN          NaN       NaN       NaN      NaN          NaN
# 10     NaN          NaN       NaN       NaN      NaN          NaN
# 11     NaN          NaN       NaN       NaN      NaN          NaN
# 12     NaN          NaN       NaN       NaN      NaN          NaN
# ...
