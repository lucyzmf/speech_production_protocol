# %%
import pandas as pd
# Out:
# /var/folders/c9/548grqkd2sl1stjqg9x96lwc0000gn/T/ipykernel_87241/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
events = pd.read_csv("../output_events/events-t-t_block3.csv")

# %%
events.keys()
# Out:
# Index(['Unnamed: 0', 'theme', 'type', 'structure', 'numer', 'tense',
#        'polarity', 'sentence', 'num_words', 'translation', 'words',
#        'num_words_translation', 'include_et', 'in_vocab',
#        'sum_word_counts_sent', 'lemmas', 'overlap', 'translation_cleaned',
#        'audio_path', 'mode', 'start_time', 'stop_time', 'duration',
#        'event_type', 'block_num', 'word', 'pos', 'is_content', 'phonemes',
#        'morphemes', 'morph_count', 'lemma', 'n_syllables', 'trial_num'],
#       dtype='object')

# %%
events
# Out:
#     Unnamed: 0         theme         type    structure     numer    tense  \
# 0      39426.0  relationship  declarative  preposition  singular  present
# 1      39426.0  relationship  declarative  preposition  singular  present
# 2      39426.0  relationship  declarative  preposition  singular  present
# 3      39426.0  relationship  declarative  preposition  singular  present
# 4      32436.0         basic  declarative  independent  singular  present
# 5      32436.0         basic  declarative  independent  singular  present
# 6          NaN           NaN          NaN          NaN       NaN      NaN
# 7          NaN           NaN          NaN          NaN       NaN      NaN
# 8          NaN           NaN          NaN          NaN       NaN      NaN
# 9          NaN           NaN          NaN          NaN       NaN      NaN
# 10      7166.0         basic  declarative        cleft    plural     past
# 11      7166.0         basic  declarative        cleft    plural     past
#
# ...
